# %%
# !pip install kaggle

# %%
from google.colab import drive
import pandas as pd
import os

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Criar o diretório .kaggle, caso não exista
os.makedirs('/root/.kaggle', exist_ok=True)

# %%
# !cp /content/drive/MyDrive/Importantes/Trabalho/kaggle.json /root/.kaggle/kaggle.json

# %%
# !kaggle datasets list -s 'Global Health Statistics'
# Out:
# ref                                                     title                                                size  lastUpdated          downloadCount  voteCount  usabilityRating
# ------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# malaiarasugraj/global-health-statistics                 Global Health Statistics                             44MB  2024-11-27 10:52:27           1741         23  1.0
# ajaypalsinghlo/world-happiness-report-2021              World Happiness Report 2021                          55KB  2021-03-22 16:51:01          79380       1364  0.9705882
# roche-data-science-coalition/uncover                    UNCOVER COVID-19 Challenge                          256MB  2023-06-07 16:52:31          26635       1337  0.875
# ...

# %%
# !kaggle datasets download -d 'malaiarasugraj/global-health-statistics'
# Out:
# Dataset URL: https://www.kaggle.com/datasets/malaiarasugraj/global-health-statistics
# License(s): CC0-1.0
# ...
#  59% 26.0M/44.3M [00:00<00:00, 136MB/s]
# 100% 44.3M/44.3M [00:00<00:00, 157MB/s]

# %%
# !unzip global-health-statistics.zip -d data/
# Out:
# Archive:  global-health-statistics.zip
#   inflating: data/Global Health Statistics.csv

# %%
df = pd.read_csv('data/Global Health Statistics.csv')

# %%
df.head()
# Out:
#      Country  Year         Disease Name Disease Category  Prevalence Rate (%)  \
# 0      Italy  2013              Malaria      Respiratory                 0.95
# 1     France  2002                Ebola        Parasitic                12.46
# 2     Turkey  2015             COVID-19          Genetic                 0.91
# 3  Indonesia  2011  Parkinson's Disease       Autoimmune                 4.68
# 4      Italy  2013         Tuberculosis          Genetic                 0.83
#
#    Incidence Rate (%)  Mortality Rate (%) Age Group Gender  \
# 0                1.55                8.42      0-18   Male
# 1                8.63                8.75       61+   Male
# 2                2.35                6.22     36-60   Male
# 3                6.29                3.99      0-18  Other
# 4               13.59                7.01       61+   Male
#
#    Population Affected  ...  Hospital Beds per 1000  Treatment Type  \
# 0               471007  ...                    7.58      Medication
# ...

# %%
df.isna().sum()
# Out:
# Country                               0
# Year                                  0
# Disease Name                          0
# Disease Category                      0
# Prevalence Rate (%)                   0
# Incidence Rate (%)                    0
# Mortality Rate (%)                    0
# Age Group                             0
# Gender                                0
# Population Affected                   0
# Healthcare Access (%)                 0
# Doctors per 1000                      0
# Hospital Beds per 1000                0
# Treatment Type                        0
# Average Treatment Cost (USD)          0
# Availability of Vaccines/Treatment    0
# Recovery Rate (%)                     0
# DALYs                                 0
# Improvement in 5 Years (%)            0
# Per Capita Income (USD)               0
# Education Index                       0
# Urbanization Rate (%)                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 22 columns):
#  #   Column                              Non-Null Count    Dtype
# ---  ------                              --------------    -----
#  0   Country                             1000000 non-null  object
#  1   Year                                1000000 non-null  int64
#  2   Disease Name                        1000000 non-null  object
#  3   Disease Category                    1000000 non-null  object
#  4   Prevalence Rate (%)                 1000000 non-null  float64
#  5   Incidence Rate (%)                  1000000 non-null  float64
#  6   Mortality Rate (%)                  1000000 non-null  float64
#  7   Age Group                           1000000 non-null  object
#  8   Gender                              1000000 non-null  object
#  9   Population Affected                 1000000 non-null  int64
# ...

# %%
df_brazil = df[df['Country'] == 'Brazil']

# %%
df_brazil
# Out:
#        Country  Year         Disease Name Disease Category  \
# 33      Brazil  2003  Parkinson's Disease            Viral
# 35      Brazil  2011  Parkinson's Disease     Neurological
# 45      Brazil  2003  Alzheimer's Disease     Neurological
# 46      Brazil  2010             HIV/AIDS       Autoimmune
# 62      Brazil  2013                Ebola        Metabolic
# ...        ...   ...                  ...              ...
# 999925  Brazil  2012  Alzheimer's Disease      Respiratory
# 999962  Brazil  2000               Rabies       Autoimmune
# 999963  Brazil  2024              Measles        Bacterial
# 999989  Brazil  2010         Hypertension        Parasitic
# 999990  Brazil  2014               Rabies        Parasitic
#
#         Prevalence Rate (%)  Incidence Rate (%)  Mortality Rate (%) Age Group  \
# 33                    13.85                4.52                3.23       61+
# 35                     6.42               10.08                0.29      0-18
# ...
